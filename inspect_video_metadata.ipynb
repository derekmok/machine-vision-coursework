# %% [markdown]
# # Video Metadata Inspector
#
# This notebook inspects every video in the `video-data` folder and extracts:
# - **Framerate** (FPS)
# - **Number of frames**
# - **Length** (duration in seconds)
#
# It also computes summary statistics for each of these fields.

# %%
import os

import cv2
import pandas as pd

# %% [markdown]
# ## Video Inspection Function

# %%
def get_video_metadata(video_path: str) -> dict:
    """
    Extract metadata from a video file.
    
    Args:
        video_path: Path to the video file
        
    Returns:
        Dictionary containing filename, framerate, frame_count, and duration
    """
    cap = cv2.VideoCapture(video_path)
    
    if not cap.isOpened():
        return {
            'filename': os.path.basename(video_path),
            'framerate': None,
            'frame_count': None,
            'duration_seconds': None,
            'error': 'Could not open video'
        }
    
    fps = cap.get(cv2.CAP_PROP_FPS)
    frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    
    duration = frame_count / fps if fps > 0 else 0
    
    cap.release()
    
    return {
        'filename': os.path.basename(video_path),
        'framerate': fps,
        'frame_count': frame_count,
        'duration_seconds': duration,
        'error': None
    }

# %% [markdown]
# ## Inspect All Videos

# %%
video_dir = './video-data'

video_extensions = ('.mp4', '.avi', '.mov', '.mkv', '.webm')
video_files = [
    os.path.join(video_dir, f) 
    for f in os.listdir(video_dir) 
    if f.lower().endswith(video_extensions)
]

print(f"Found {len(video_files)} video files in '{video_dir}'")
# Out:
# Found 77 video files in './video-data'

# %%
metadata_list = []

for video_path in sorted(video_files):
    metadata = get_video_metadata(video_path)
    metadata_list.append(metadata)
    
df = pd.DataFrame(metadata_list)

# %% [markdown]
# ## Video Metadata Table

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

df_display = df[['filename', 'framerate', 'frame_count', 'duration_seconds']].copy()
df_display['duration_seconds'] = df_display['duration_seconds'].round(2)
df_display
# Out:
#                                              filename  framerate  frame_count  \
# 0                                   1_dksksjfwijf.mp4  29.839151          169
# 1                               2_dfsaeklnvvalkej.mp4  29.526883          129
# 2                                   2_difficult_2.mp4  29.814735          173
# 3                       2_difficult_sdafkljsalkfj.mp4  29.606801          114
# 4                                   2_dkdjwkndkfw.mp4  29.970030          200
# 5                                 2_dkdmkejkeimdh.mp4  29.658922          174
# 6                                    2_dkjd823kjf.mp4  23.607410          241
# 7                              2_dsalkfjalwkenlke.mp4  23.640824          208
# 8   2_kling_20251205_Text_to_Video_On_a_sandy_4976...  24.000000          121
# 9   2_kling_20251206_Text_to_Video_Generate_a_71_1...  24.000000           96
# 10                           2_sadfasjldkfjaseifj.mp4  29.774352          159
# 11                         2_sdafkjaslkclaksdjkas.mp4  23.230548          121
# 12                          2_sdfkjsaleijflaskdjf.mp4  29.670362          200
# 13                              2_sdjfhafsldkjhjk.mp4  29.672430          177
# 14                                2_sdkjdsflkjfwa.mp4  29.911896          165
# 15                                2_sdlfjlewlkjkj.mp4  23.607410          241
# 16                            2_sdlkjsaelijfksdjf.mp4  29.970030          200
# 17                       3_asldkfjalwieaskdfaskdf.mp4  23.607410          241
# 18                             3_dkk873lkjlksajdf.mp4  23.631186          218
# 19                             3_dsjlaeijlksjdfie.mp4  54.842898          150
# 20                                3_dsksdfjbvsdkj.mp4  29.670362          200
# 21                             3_dslkaldskjflakjs.mp4  23.607410          241
# 22                         3_ewdfkjwaeoihjlkasdjf.mp4  29.670362          200
# 23  3_kling_20251205_Text_to_Video_In_a_grass_4697...  24.000000          121
# 24  3_kling_20251205_Text_to_Video_On_a_playg_5028...  24.000000          192
# 25  3_kling_20251205_Text_to_Video_On_a_playg_5064...  24.000000          192
# 26  3_kling_20251206_Text_to_Video_Generate_a_17_0...  24.000000          192
# 27  3_kling_20251206_Text_to_Video_Generate_a_315_...  24.000000          241
# 28  3_kling_20251206_Text_to_Video_Generate_a_315_...  24.000000          216
# 29  3_kling_20251206_Text_to_Video_Generate_a_712_...  24.000000          241
# 30  3_kling_20251206_Text_to_Video_Generate_a_71_0...  24.000000          121
# 31  3_kling_20251206_Text_to_Video_Generate_a_71_2...  24.000000          121
# 32  3_kling_20251206_Text_to_Video_Generate_a_71_3...  24.000000          121
# 33  3_kling_20251209_Image_to_Video_Generate_a_613...  24.000000          241
# 34  3_kling_20251209_Image_to_Video_Generate_a_635...  24.000000          241
# 35  3_kling_20251209_Text_to_Video_Generate_a_190_...  24.000000          241
# 36  3_kling_20251209_Text_to_Video_Generate_a_403_...  24.000000          241
# 37  3_kling_20251209_Text_to_Video_Generate_a_491_...  24.000000          241
# 38  3_kling_20251209_Text_to_Video_Generate_a_491_...  24.000000          241
# 39  3_kling_20251209_Text_to_Video_Generate_a_491_...  24.000000          241
# 40                                3_kling_dskfseu.mp4  23.607410          241
# 41                            3_kling_kdjflaskdjf.mp4  23.604738          211
# 42                           3_sadklfjasbnlkjlfkj.mp4  29.670362          200
# 43                    3_sadlfkjasldkfjasleijlkjfd.mp4  23.635596          226
# 44                          3_sadlfkjawelnflksdjf.mp4  29.885151          172
# 45                            3_sdfjwaiejflkasjdf.mp4  29.910107          184
# 46                               3_sdflkjliejkjdf.mp4  29.726610          188
# 47                             3_sdlkfjaleknaksej.mp4  23.636777          227
# 48                              3_sdlkfjalkjejafe.mp4  23.607410          241
# 49                          3_sdlkjfaslkjfalskjdf.mp4  23.607410          241
# 50                        3_sdlkjslndflkseijlkjef.mp4  23.625748          190
# 51      4_20251209_Text_to_Video_Generate_a_561_0.mp4  24.000000          241
# 52                             4_asdlkfjalsflnekj.mp4  23.607410          241
# 53                              4_aslkcasckmwlejk.mp4  23.607410          241
# 54                          4_aslkjasmcalkewjlkje.mp4  23.613867          223
# 55                              4_dssalsdkfjweijf.mp4  29.847592          113
# 56  4_kling_20251206_Text_to_Video_Generate_a_28_0...  24.000000          241
# 57  4_kling_20251206_Text_to_Video_Generate_a_315_...  24.000000          241
# 58  4_kling_20251206_Text_to_Video_Generate_a_58_0...  24.000000          241
# 59  4_kling_20251207_Text_to_Video_Generate_a_521_...  24.000000          241
# 60  4_kling_20251209_Image_to_Video_Generate_a_635...  24.000000          241
# 61  4_kling_20251209_Text_to_Video_Generate_a_190_...  24.000000          241
# 62  4_kling_20251209_Text_to_Video_Generate_a_218_...  24.000000          241
# 63  4_kling_20251209_Text_to_Video_Generate_a_263_...  24.000000          241
# 64  4_kling_20251209_Text_to_Video_Generate_a_377_...  24.000000          241
# 65  4_kling_20251209_Text_to_Video_Generate_a_452_...  24.000000          241
# 66  4_kling_20251209_Text_to_Video_Generate_a_452_...  24.000000          241
# 67  4_kling_20251209_Text_to_Video_Generate_a_561_...  24.000000          241
# 68  4_kling_20251209_Text_to_Video_Generate_a_588_...  24.000000          241
# 69  4_pushup_1f2da596-7619-4d55-9376-069e15a42a1a_...  23.976024          325
# 70                         4_sadflkjasldkjfalseij.mp4  23.951651          179
# 71                            4_sadlfkjlknewkjejk.mp4  23.607410          241
# 72                        5_sadfjhaslfkjasdlkfjsa.mp4  29.670362          200
# 73                    5_sdfkljweoijlkjdsflkjweaij.mp4  59.429725          184
# 74                           6_dfjewaijsldkjfsaef.mp4  29.893284          186
# 75  6_kling_20251209_Text_to_Video_Generate_a_218_...  24.000000          241
# 76                                 7_sadkjfkljekj.mp4  29.846846          198
#
#     duration_seconds
# 0               5.66
# 1               4.37
# 2               5.80
# 3               3.85
# 4               6.67
# 5               5.87
# 6              10.21
# 7               8.80
# 8               5.04
# 9               4.00
# 10              5.34
# 11              5.21
# 12              6.74
# 13              5.97
# 14              5.52
# 15             10.21
# 16              6.67
# 17             10.21
# 18              9.23
# 19              2.74
# 20              6.74
# 21             10.21
# 22              6.74
# 23              5.04
# 24              8.00
# 25              8.00
# 26              8.00
# 27             10.04
# 28              9.00
# 29             10.04
# 30              5.04
# 31              5.04
# 32              5.04
# 33             10.04
# 34             10.04
# 35             10.04
# 36             10.04
# 37             10.04
# 38             10.04
# 39             10.04
# 40             10.21
# 41              8.94
# 42              6.74
# 43              9.56
# 44              5.76
# 45              6.15
# 46              6.32
# 47              9.60
# 48             10.21
# 49             10.21
# 50              8.04
# 51             10.04
# 52             10.21
# 53             10.21
# 54              9.44
# 55              3.79
# 56             10.04
# 57             10.04
# 58             10.04
# 59             10.04
# 60             10.04
# 61             10.04
# 62             10.04
# 63             10.04
# 64             10.04
# 65             10.04
# 66             10.04
# 67             10.04
# 68             10.04
# 69             13.56
# 70              7.47
# 71             10.21
# 72              6.74
# 73              3.10
# 74              6.22
# 75             10.04
# 76              6.63

# %% [markdown]
# ## Summary Statistics

# %%
df_valid = df[df['error'].isna()].copy()

stats_columns = ['framerate', 'frame_count', 'duration_seconds']

summary_stats_df = df_valid[stats_columns].describe().round(2)
summary_stats_df
# Out:
#        framerate  frame_count  duration_seconds
# count      77.00        77.00             77.00
# mean       26.34       205.84              8.12
# std         5.72        44.69              2.34
# min        23.23        96.00              2.74
# 25%        23.98       184.00              6.15
# 50%        24.00       218.00              9.23
# 75%        29.67       241.00             10.04
# max        59.43       325.00             13.56

# %%
unique_fps = sorted(df_valid['framerate'].unique())
most_common_fps = df_valid['framerate'].mode().values[0]
min_frame_idx = df_valid['frame_count'].idxmin()
max_frame_idx = df_valid['frame_count'].idxmax()
total_duration_sec = df_valid['duration_seconds'].sum()
total_duration_min = total_duration_sec / 60
min_duration_idx = df_valid['duration_seconds'].idxmin()
max_duration_idx = df_valid['duration_seconds'].idxmax()

insights_data = {
    'Category': [
        'Overview', 'Overview',
        'Framerate', 'Framerate',
        'Frame Count', 'Frame Count', 'Frame Count',
        'Duration', 'Duration', 'Duration'
    ],
    'Metric': [
        'Total videos analyzed',
        'Videos with errors',
        'Unique framerates',
        'Most common FPS',
        'Total frames (all videos)',
        'Shortest video',
        'Longest video',
        'Total duration',
        'Shortest video',
        'Longest video'
    ],
    'Value': [
        str(len(df_valid)),
        str(len(df) - len(df_valid)),
        ', '.join([f"{fps:.2f}" for fps in unique_fps]),
        f"{most_common_fps:.2f}",
        f"{df_valid['frame_count'].sum():,}",
        f"{df_valid.loc[min_frame_idx, 'filename']} ({df_valid['frame_count'].min()} frames)",
        f"{df_valid.loc[max_frame_idx, 'filename']} ({df_valid['frame_count'].max()} frames)",
        f"{total_duration_sec:.2f} seconds ({total_duration_min:.2f} minutes)",
        f"{df_valid.loc[min_duration_idx, 'filename']} ({df_valid['duration_seconds'].min():.2f}s)",
        f"{df_valid.loc[max_duration_idx, 'filename']} ({df_valid['duration_seconds'].max():.2f}s)"
    ]
}

insights_df = pd.DataFrame(insights_data)
insights_df
# Out:
#       Category                     Metric  \
# 0     Overview      Total videos analyzed
# 1     Overview         Videos with errors
# 2    Framerate          Unique framerates
# 3    Framerate            Most common FPS
# 4  Frame Count  Total frames (all videos)
# 5  Frame Count             Shortest video
# 6  Frame Count              Longest video
# 7     Duration             Total duration
# 8     Duration             Shortest video
# 9     Duration              Longest video
#
#                                                Value
# 0                                                 77
# 1                                                  0
# 2  23.23, 23.60, 23.61, 23.61, 23.63, 23.63, 23.6...
# 3                                              24.00
# 4                                             15,850
# 5  2_kling_20251206_Text_to_Video_Generate_a_71_1...
# 6  4_pushup_1f2da596-7619-4d55-9376-069e15a42a1a_...
# 7                     625.27 seconds (10.42 minutes)
# 8                     3_dsjlaeijlksjdfie.mp4 (2.74s)
# 9  4_pushup_1f2da596-7619-4d55-9376-069e15a42a1a_...

# %% [markdown]
# ## Grouped Statistics by Label

# %%
df_valid['label'] = df_valid['filename'].apply(lambda x: x.split('_')[0])

grouped_df = df_valid.groupby('label').agg({
    'filename': 'count',
    'framerate': ['mean', 'std'],
    'frame_count': ['mean', 'std', 'min', 'max'],
    'duration_seconds': ['mean', 'std', 'min', 'max']
}).round(2)

grouped_df.columns = ['_'.join(col).strip() for col in grouped_df.columns.values]
grouped_df = grouped_df.rename(columns={'filename_count': 'video_count'})
grouped_df
# Out:
#        video_count  framerate_mean  framerate_std  frame_count_mean  \
# label
# 1                1           29.84            NaN            169.00
# 2               16           27.48           3.05            169.94
# 3               34           25.81           5.61            206.35
# 4               21           24.20           1.30            235.10
# 5                2           44.55          21.04            192.00
# 6                2           26.95           4.17            213.50
# 7                1           29.85            NaN            198.00
#
#        frame_count_std  frame_count_min  frame_count_max  \
# label
# 1                  NaN              169              169
# 2                44.38               96              241
# 3                40.15              121              241
# 4                36.66              113              325
# 5                11.31              184              200
# 6                38.89              186              241
# 7                  NaN              198              198
#
#        duration_seconds_mean  duration_seconds_std  duration_seconds_min  \
# label
# 1                       5.66                   NaN                  5.66
# 2                       6.27                  1.95                  3.85
# 3                       8.27                  2.11                  2.74
# 4                       9.78                  1.69                  3.79
# 5                       4.92                  2.58                  3.10
# 6                       8.13                  2.70                  6.22
# 7                       6.63                   NaN                  6.63
#
#        duration_seconds_max
# label
# 1                      5.66
# 2                     10.21
# 3                     10.21
# 4                     13.56
# 5                      6.74
# 6                     10.04
# 7                      6.63
