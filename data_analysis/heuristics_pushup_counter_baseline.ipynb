# %% [markdown]
# # Heuristic based push-up counter
#
# This file uses a signal processing approach instead of deep learning.
# The key insight is that during a push-up, the shoulder elbow angle oscillates
# periodically. We detect these oscillations using peak detection.
#
# This serves as a BASELINE for comparison with deep learning approaches.

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader


from data_loader import VideoDataset

def get_dataloaders(video_dir, batch_size=4, val_split=0.2):
    """Create train and validation dataloaders for landmark sequences.
    
    Args:
        video_dir: Path to directory containing video files.
        batch_size: Number of samples per batch.
        val_split: Fraction of data to use for validation.
        
    Returns:
        train_loader: DataLoader for training data.
        val_loader: DataLoader for validation data.
    """
    
    # First, create a dataset without transforms to determine the split indices
    full_dataset = VideoDataset(video_dir, transform=None)
    
    val_size = int(len(full_dataset) * val_split)
    train_size = len(full_dataset) - val_size

    # Get the indices for train and validation splits
    generator = torch.Generator().manual_seed(42)
    indices = torch.randperm(len(full_dataset), generator=generator).tolist()
    train_indices = indices[:train_size]
    val_indices = indices[train_size:]
    
    # Create separate datasets for train (with augmentation) and val (without)
    train_dataset = VideoDataset(video_dir)
    val_dataset = VideoDataset(video_dir)
    
    # Use Subset to apply the split indices
    from torch.utils.data import Subset
    train_subset = Subset(train_dataset, train_indices)
    val_subset = Subset(val_dataset, val_indices)

    train_loader = DataLoader(
        train_subset,
        batch_size=batch_size,
        shuffle=True,
        num_workers=0,
    )

    val_loader = DataLoader(
        val_subset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=0,
    )

    print(f"Train: {len(train_subset)} videos, Val: {len(val_subset)} videos")
    
    return train_loader, val_loader


video_dir = '../video-data'

# %%
from count_pushups_heuristic import (
    HeuristicPushupCounter,
    evaluate_on_dataset,
    grid_search_parameters,
)

# %% [markdown]
# # Evaluate the Heuristic Model
#
# Since this is a heuristic approach (not learned), there is no "training" phase.
# Instead, we evaluate the signal processing based counter on our data and tune
# the hyperparameters using grid search.

# %%
def run_heuristic_evaluation(
    video_dir: str = './video-data',
):
    """Evaluate the heuristic push-up counter on the dataset.
    
    Args:
        video_dir: Path to the video data directory.
    """
    train_loader, val_loader = get_dataloaders(video_dir, batch_size=1, val_split=0.2)
    
    print("Running grid search for optimal parameters...")
    
    # Use training set for parameter tuning
    search_results = grid_search_parameters(
        train_loader,
        smoothing_windows=[11, 15, 21, 31],
        min_prominences=[0.03, 0.05, 0.08, 0.11],
        min_distances=[5, 10, 15, 20, 30],
    )
    
    print(f"Best parameters: {search_results['best_params']}")
    print(f"Best MAE on training set: {search_results['best_mae']:.4f}")
    
    counter = HeuristicPushupCounter(**search_results['best_params'])
    
    # Evaluate on training set
    print("Training Set Results:")
    train_metrics = evaluate_on_dataset(train_loader, counter)
    print(f"MAE: {train_metrics['mae']:.4f}")
    print(f"Exact Accuracy: {train_metrics['accuracy'] * 100:.2f}%")
    print(f"Within-1 Accuracy: {train_metrics['within_1_accuracy'] * 100:.2f}%")
    
    # Per-sample breakdown
    print("\nPer-sample breakdown:")
    for pred, label in zip(train_metrics['predictions'], train_metrics['labels']):
        status = "✓" if pred == label else "✗"
        print(f"{status} Predicted: {pred}, Actual: {label}")
    
    # Evaluate on validation set
    print()
    print("Validation Set Results:")
    val_metrics = evaluate_on_dataset(val_loader, counter)
    print(f"MAE: {val_metrics['mae']:.4f}")
    print(f"Exact Accuracy: {val_metrics['accuracy'] * 100:.2f}%")
    print(f"Within-1 Accuracy: {val_metrics['within_1_accuracy'] * 100:.2f}%")
    
    # Per-sample breakdown
    print("\nPer-sample breakdown:")
    for pred, label in zip(val_metrics['predictions'], val_metrics['labels']):
        status = "✓" if pred == label else "✗"
        print(f"{status} Predicted: {pred}, Actual: {label}")
    
    print()
    print("EVALUATION COMPLETE")
    
    return counter, train_metrics, val_metrics

# %%
# Run the evaluation
counter, train_metrics, val_metrics = run_heuristic_evaluation(
    video_dir='../video-data',
)
# Out:
# Train: 62 videos, Val: 15 videos
# Running grid search for optimal parameters...
# [1/80] Testing window=11, prominence=0.03, distance=5
#   -> New best MAE: 0.6290
# [2/80] Testing window=11, prominence=0.03, distance=10
#   -> New best MAE: 0.5806
# [3/80] Testing window=11, prominence=0.03, distance=15
#   -> New best MAE: 0.4355
# [4/80] Testing window=11, prominence=0.03, distance=20
#   -> New best MAE: 0.3710
# [5/80] Testing window=11, prominence=0.03, distance=30
#   -> New best MAE: 0.2581
# [6/80] Testing window=11, prominence=0.05, distance=5
# [7/80] Testing window=11, prominence=0.05, distance=10
# [8/80] Testing window=11, prominence=0.05, distance=15
# [9/80] Testing window=11, prominence=0.05, distance=20
# [10/80] Testing window=11, prominence=0.05, distance=30
#   -> New best MAE: 0.2419
# [11/80] Testing window=11, prominence=0.08, distance=5
# [12/80] Testing window=11, prominence=0.08, distance=10
# [13/80] Testing window=11, prominence=0.08, distance=15
# [14/80] Testing window=11, prominence=0.08, distance=20
# [15/80] Testing window=11, prominence=0.08, distance=30
#   -> New best MAE: 0.2097
# [16/80] Testing window=11, prominence=0.11, distance=5
# [17/80] Testing window=11, prominence=0.11, distance=10
# [18/80] Testing window=11, prominence=0.11, distance=15
#   -> New best MAE: 0.1935
# [19/80] Testing window=11, prominence=0.11, distance=20
# [20/80] Testing window=11, prominence=0.11, distance=30
# [21/80] Testing window=15, prominence=0.03, distance=5
# [22/80] Testing window=15, prominence=0.03, distance=10
# [23/80] Testing window=15, prominence=0.03, distance=15
# [24/80] Testing window=15, prominence=0.03, distance=20
# [25/80] Testing window=15, prominence=0.03, distance=30
# [26/80] Testing window=15, prominence=0.05, distance=5
# [27/80] Testing window=15, prominence=0.05, distance=10
# [28/80] Testing window=15, prominence=0.05, distance=15
# [29/80] Testing window=15, prominence=0.05, distance=20
# [30/80] Testing window=15, prominence=0.05, distance=30
# [31/80] Testing window=15, prominence=0.08, distance=5
#   -> New best MAE: 0.1774
# [32/80] Testing window=15, prominence=0.08, distance=10
# [33/80] Testing window=15, prominence=0.08, distance=15
# [34/80] Testing window=15, prominence=0.08, distance=20
# [35/80] Testing window=15, prominence=0.08, distance=30
# [36/80] Testing window=15, prominence=0.11, distance=5
#   -> New best MAE: 0.1452
# [37/80] Testing window=15, prominence=0.11, distance=10
# [38/80] Testing window=15, prominence=0.11, distance=15
# [39/80] Testing window=15, prominence=0.11, distance=20
# [40/80] Testing window=15, prominence=0.11, distance=30
# [41/80] Testing window=21, prominence=0.03, distance=5
# [42/80] Testing window=21, prominence=0.03, distance=10
# [43/80] Testing window=21, prominence=0.03, distance=15
# [44/80] Testing window=21, prominence=0.03, distance=20
# [45/80] Testing window=21, prominence=0.03, distance=30
# [46/80] Testing window=21, prominence=0.05, distance=5
# [47/80] Testing window=21, prominence=0.05, distance=10
# [48/80] Testing window=21, prominence=0.05, distance=15
# [49/80] Testing window=21, prominence=0.05, distance=20
# [50/80] Testing window=21, prominence=0.05, distance=30
# [51/80] Testing window=21, prominence=0.08, distance=5
# [52/80] Testing window=21, prominence=0.08, distance=10
# [53/80] Testing window=21, prominence=0.08, distance=15
# [54/80] Testing window=21, prominence=0.08, distance=20
#   -> New best MAE: 0.1129
# [55/80] Testing window=21, prominence=0.08, distance=30
# [56/80] Testing window=21, prominence=0.11, distance=5
#   -> New best MAE: 0.0968
# [57/80] Testing window=21, prominence=0.11, distance=10
# [58/80] Testing window=21, prominence=0.11, distance=15
# [59/80] Testing window=21, prominence=0.11, distance=20
# [60/80] Testing window=21, prominence=0.11, distance=30
# [61/80] Testing window=31, prominence=0.03, distance=5
# [62/80] Testing window=31, prominence=0.03, distance=10
# [63/80] Testing window=31, prominence=0.03, distance=15
# [64/80] Testing window=31, prominence=0.03, distance=20
# [65/80] Testing window=31, prominence=0.03, distance=30
# [66/80] Testing window=31, prominence=0.05, distance=5
# [67/80] Testing window=31, prominence=0.05, distance=10
# [68/80] Testing window=31, prominence=0.05, distance=15
# [69/80] Testing window=31, prominence=0.05, distance=20
# [70/80] Testing window=31, prominence=0.05, distance=30
# [71/80] Testing window=31, prominence=0.08, distance=5
# [72/80] Testing window=31, prominence=0.08, distance=10
# [73/80] Testing window=31, prominence=0.08, distance=15
# [74/80] Testing window=31, prominence=0.08, distance=20
# [75/80] Testing window=31, prominence=0.08, distance=30
# [76/80] Testing window=31, prominence=0.11, distance=5
# [77/80] Testing window=31, prominence=0.11, distance=10
# [78/80] Testing window=31, prominence=0.11, distance=15
# [79/80] Testing window=31, prominence=0.11, distance=20
# [80/80] Testing window=31, prominence=0.11, distance=30
# Best parameters: {'smoothing_window': 21, 'poly_order': 3, 'min_prominence': 0.11, 'min_distance': 5}
# Best MAE on training set: 0.0968
# Training Set Results:
# MAE: 0.0968
# Exact Accuracy: 91.94%
# Within-1 Accuracy: 98.39%
#
# Per-sample breakdown:
# ✓ Predicted: 5, Actual: 5
# ✓ Predicted: 4, Actual: 4
# ✓ Predicted: 4, Actual: 4
# ✓ Predicted: 6, Actual: 6
# ✓ Predicted: 3, Actual: 3
# ✓ Predicted: 3, Actual: 3
# ✓ Predicted: 1, Actual: 1
# ✗ Predicted: 4, Actual: 2
# ✓ Predicted: 3, Actual: 3
# ✗ Predicted: 4, Actual: 3
# ✓ Predicted: 4, Actual: 4
# ✓ Predicted: 2, Actual: 2
# ✓ Predicted: 2, Actual: 2
# ✓ Predicted: 3, Actual: 3
# ✓ Predicted: 3, Actual: 3
# ✓ Predicted: 3, Actual: 3
# ✓ Predicted: 3, Actual: 3
# ✓ Predicted: 4, Actual: 4
# ✓ Predicted: 4, Actual: 4
# ✓ Predicted: 2, Actual: 2
# ✓ Predicted: 4, Actual: 4
# ✓ Predicted: 3, Actual: 3
# ✓ Predicted: 2, Actual: 2
# ✓ Predicted: 4, Actual: 4
# ✓ Predicted: 4, Actual: 4
# ✗ Predicted: 4, Actual: 3
# ✓ Predicted: 2, Actual: 2
# ✓ Predicted: 3, Actual: 3
# ✓ Predicted: 2, Actual: 2
# ✓ Predicted: 3, Actual: 3
# ✓ Predicted: 2, Actual: 2
# ✓ Predicted: 4, Actual: 4
# ✓ Predicted: 3, Actual: 3
# ✓ Predicted: 4, Actual: 4
# ✓ Predicted: 2, Actual: 2
# ✓ Predicted: 2, Actual: 2
# ✓ Predicted: 3, Actual: 3
# ✗ Predicted: 4, Actual: 3
# ✓ Predicted: 3, Actual: 3
# ✓ Predicted: 2, Actual: 2
# ✓ Predicted: 4, Actual: 4
# ✓ Predicted: 4, Actual: 4
# ✓ Predicted: 3, Actual: 3
# ✓ Predicted: 2, Actual: 2
# ✓ Predicted: 3, Actual: 3
# ✓ Predicted: 4, Actual: 4
# ✓ Predicted: 2, Actual: 2
# ✓ Predicted: 4, Actual: 4
# ✓ Predicted: 4, Actual: 4
# ✓ Predicted: 4, Actual: 4
# ✓ Predicted: 3, Actual: 3
# ✓ Predicted: 4, Actual: 4
# ✓ Predicted: 3, Actual: 3
# ✓ Predicted: 4, Actual: 4
# ✓ Predicted: 3, Actual: 3
# ✓ Predicted: 3, Actual: 3
# ✓ Predicted: 3, Actual: 3
# ✓ Predicted: 3, Actual: 3
# ✓ Predicted: 3, Actual: 3
# ✓ Predicted: 4, Actual: 4
# ✓ Predicted: 6, Actual: 6
# ✗ Predicted: 3, Actual: 2
#
# Validation Set Results:
# MAE: 0.0000
# Exact Accuracy: 100.00%
# Within-1 Accuracy: 100.00%
#
# Per-sample breakdown:
# ✓ Predicted: 5, Actual: 5
# ✓ Predicted: 3, Actual: 3
# ✓ Predicted: 2, Actual: 2
# ✓ Predicted: 3, Actual: 3
# ✓ Predicted: 3, Actual: 3
# ✓ Predicted: 4, Actual: 4
# ✓ Predicted: 4, Actual: 4
# ✓ Predicted: 3, Actual: 3
# ✓ Predicted: 3, Actual: 3
# ✓ Predicted: 3, Actual: 3
# ✓ Predicted: 2, Actual: 2
# ✓ Predicted: 3, Actual: 3
# ✓ Predicted: 3, Actual: 3
# ✓ Predicted: 3, Actual: 3
# ✓ Predicted: 7, Actual: 7
#
# EVALUATION COMPLETE

# %% [markdown]
# Visualize the signal processing on sample videos to understand how the heuristic works.

# %%
import matplotlib.pyplot as plt

# Visualize detection on a few sample videos
def visualize_sample_detections(video_dir: str = './video-data', num_samples: int = 3):
    """Visualize the push-up detection on sample videos."""
    dataset = VideoDataset(video_dir)
    
    fig, axes = plt.subplots(num_samples, 1, figsize=(14, 4 * num_samples))
    if num_samples == 1:
        axes = [axes]
    
    for i in range(min(num_samples, len(dataset))):
        landmarks, label, _ = dataset[i]
        counter.plot_debug(
            landmarks, 
            title=f"Video {i+1} (Ground Truth: {label} push-ups)",
            ax=axes[i]
        )
    
    plt.tight_layout()
    plt.savefig('pushup_detection_visualization.png', dpi=150, bbox_inches='tight')
    plt.show()
    print("Saved visualization to 'pushup_detection_visualization.png'")

visualize_sample_detections()
# Out:
# Saved visualization to 'pushup_detection_visualization.png'
